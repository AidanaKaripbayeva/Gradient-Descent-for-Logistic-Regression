# %%
import numpy as np
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
# %pylab inline
import matplotlib.pyplot as plt
from matplotlib import style
style.use('ggplot')
import random as ran
import matplotlib.pyplot as pl
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
iris = load_iris()
X = iris.data[:100]
y = iris.target[:100]

# split the data with 80% in train set
X1, X2, y1, y2 = train_test_split(X, y, random_state=0,
                                  train_size=0.8)


#n, d = X1.shape
T = 2000 # learning steps
alpha = 0.001 # learning rate
Ein = []
Eout = []


def fit(x, y):
    n, d = x.shape
    w = np.zeros(d, dtype=float)

    for i in range(T):
        s1 = s2 = ein = eout = 0
    
        k = random.randint(0, len(x) - 1)
        grad = (-2)*y[k]*x[k] / (1 + np.exp(y[k]*(-2*np.dot(w, x[k])) ))
        w = w - alpha * grad
        ein = np.log(1 + np.exp(-y[k]*(2*np.dot(w, x[k]))))
        s1 = s1 + ein
            
        j = random.randint(0, len(X2) - 1)
        eout = np.log(1 + np.exp(-y2[j]*(2*np.dot(w, X2[j]))))
        s2 = s2 + eout
            
        Ein.append(s1/len(x))
        Eout.append(s2/len(X2))
            
    return w, Ein, Eout

X1 = insert(X1, 0, ones(len(X1)), axis=1)
X2 = insert(X2, 0, ones(len(X2)), axis=1)
w_train, Ein, Eout = fit(X1, y1)

# %%
#Plotting the graph of Ein and Eout versus the number of iteratios
t = [x for x in range(T)]
plt.ylabel('In sample Error')
plt.xlabel('Number of iterations')
plt.plot(t, Ein, color = 'b', label = "In sample error")
plt.plot(t, Eout, color = 'r', label = "Out of sample error")
plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)
plt.show()

# %% [markdown]
# ***As we can see from the graph the in sample error and out of sample error is quite small ranging from 0 to 0.035(Out-of-sample) and from 0 to 0.009(in-sampleO. As we are using Gradient Descent and everytime we pick a random number, our out-of-sample error bouncing from 0 to 0.035. That is why we see a blue or red box. Also, if we increase the number of iteration to 10000, then, our out-of-sample error decreases considerably ranging from 0 to 0.009. This means that we are indeed minimizing both, in sample and out of sample errors ***
